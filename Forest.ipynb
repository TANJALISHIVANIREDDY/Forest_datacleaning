# %%
import pandas as pd
import numpy as np
import scipy as sc
import math

# %% [markdown]
# import xlsx file

# %%
data_1=pd.read_excel('data_1.xlsx')

# %%
data_1.columns
# Out:
# Index(['State/ Uts', 'Geographical Area',
#        '2013 Assessment - Very Dense Forest',
#        '2013 Assessment - Mod. Dense Forest',
#        '2013 Assessment - Open Forest Forest',
#        '2013 Assessment - Total Forest Forest', 'Percent of Geographical Area',
#        'Change in Forest Cover wrt ISFR 2011', 'Change percent', 'Scrub'],
#       dtype='object')

# %%
data_1.head()
# Out:
#           State/ Uts Geographical Area  ... Change percent   Scrub
# 0     Andhra Pradesh          2,75,069  ...          -0.10  10,465
# 1  Arunachal Pradesh            83,743  ...          -0.11     121
# 2              Assam            78,438  ...           0.00     182
# 3              Bihar            94,163  ...           0.47     115
# 4       Chhattisgarh          1,35,191  ...          -0.04     117
#
# [5 rows x 10 columns]

# %%
data_1.isnull().sum()
# Out:
# State/ Uts                               0
# Geographical Area                        0
# 2013 Assessment - Very Dense Forest      0
# 2013 Assessment - Mod. Dense Forest      0
# 2013 Assessment - Open Forest Forest     0
# 2013 Assessment - Total Forest Forest    0
# Percent of Geographical Area             0
# Change in Forest Cover wrt ISFR 2011     0
# Change percent                           0
# Scrub                                    0
# dtype: int64

# %%
data_1.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                         object
# 2013 Assessment - Very Dense Forest       object
# 2013 Assessment - Mod. Dense Forest       object
# 2013 Assessment - Open Forest Forest      object
# 2013 Assessment - Total Forest Forest     object
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# Scrub                                     object
# dtype: object

# %%
data_1['2013 Assessment - Very Dense Forest']=data_1['2013 Assessment - Very Dense Forest'].str.replace(',','').astype(float)

# %%
data_1['Geographical Area']=data_1['Geographical Area'].str.replace(',','').astype(float)
data_1['2013 Assessment - Mod. Dense Forest']=data_1['2013 Assessment - Mod. Dense Forest'].str.replace(',','').astype(float)
data_1['2013 Assessment - Open Forest Forest']=data_1['2013 Assessment - Open Forest Forest'].str.replace(',','').astype(float)
data_1['2013 Assessment - Total Forest Forest']=data_1['2013 Assessment - Total Forest Forest'].str.replace(',','').astype(float)

# %%
data_1.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                        float64
# 2013 Assessment - Very Dense Forest      float64
# 2013 Assessment - Mod. Dense Forest      float64
# 2013 Assessment - Open Forest Forest     float64
# 2013 Assessment - Total Forest Forest    float64
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# Scrub                                     object
# dtype: object

# %%
data_1.at[28,'State/ Uts']='West Bengal'
data_1.at[14,'State/ Uts']='Madhya Pradesh'
data_1.at[10,'State/ Uts']='Jammu and Kashmir'

# %%
data_1
# Out:
#               State/ Uts  Geographical Area  ...  Change percent   Scrub
# 0         Andhra Pradesh           275069.0  ...           -0.10  10,465
# 1      Arunachal Pradesh            83743.0  ...           -0.11     121
# 2                  Assam            78438.0  ...            0.00     182
# 3                  Bihar            94163.0  ...            0.47     115
# 4           Chhattisgarh           135191.0  ...           -0.04     117
# 5                  Delhi             1483.0  ...            0.24    2.24
# 6                    Goa             3702.0  ...            0.00       0
# 7                Gujarat           196022.0  ...            0.02   1,492
# 8                Haryana            44212.0  ...           -0.05     150
# 9       Himachal Pradesh            55673.0  ...            0.01     298
# 10     Jammu and Kashmir           222236.0  ...            0.00   2,105
# 11             Jharkhand            79714.0  ...            0.62     670
# ...

# %%
data_1.to_csv('2013_statewise_forest_area_india.csv')

# %% [markdown]
# Year wise data

# %%
data_2=pd.read_excel('data_2.xls')
data_2
# Out:
#                                            Unnamed: 0  ...       Unnamed: 15
# 0                                                 NaN  ...               NaN
# 1                                ENVIRONMENT & FOREST  ...               NaN
# 2                                                 NaN  ...               NaN
# 3   Table 33.2 - STATEWISE FORESTS COVER OF THE CO...  ...               NaN
# 4                                                 NaN  ...         (Sq.Kms.)
# 5                                                 NaN  ...               NaN
# 6                                                Year  ...              Non-
# 7                                                 NaN  ...            Forest
# 8                                                 NaN  ...               NaN
# 9                                                 NaN  ...               NaN
# 10                                                NaN  ...               NaN
# ...

# %%
data_2.isnull().sum()
# Out:
# Unnamed: 0     10
# Unnamed: 1     13
# Unnamed: 2     23
# Unnamed: 3     12
# Unnamed: 4     23
# Unnamed: 5     12
# Unnamed: 6     23
# Unnamed: 7     12
# Unnamed: 8     23
# Unnamed: 9     13
# Unnamed: 10    23
# Unnamed: 11    13
# Unnamed: 12    23
# Unnamed: 13    14
# Unnamed: 14    23
# Unnamed: 15    12
# dtype: int64

# %%
data_miss=data_2.isnull().sum().sum()
data_miss
# Out:
# 272

# %%
total_2=np.product(data_2.shape)
total_2
# Out:
# 368

# %%
per=(data_miss/total_2)*100
per
# Out:
# 73.91304347826086

# %%
data_2.transpose()
# Out:
#               0   ...                                                 22
# Unnamed: 0   NaN  ...   @ The term Dense Forest was in use till SFR 2...
# Unnamed: 1   NaN  ...                                                NaN
# Unnamed: 2   NaN  ...                                                NaN
# Unnamed: 3   NaN  ...                                                NaN
# Unnamed: 4   NaN  ...                                                NaN
# Unnamed: 5   NaN  ...                                                NaN
# Unnamed: 6   NaN  ...                                                NaN
# Unnamed: 7   NaN  ...                                                NaN
# Unnamed: 8   NaN  ...                                                NaN
# Unnamed: 9   NaN  ...                                                NaN
# Unnamed: 10  NaN  ...                                                NaN
# Unnamed: 11  NaN  ...                                                NaN
# ...

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/sg-008/Data-of-Indian-Forests/main/2019_Forest_Cover_in_the_States_India.csv')

# %%
data
# Out:
#        S.              State/UT       Geo.  ...     Change Change.1   Scrub
# 0     No.                   NaN  Area (GA)  ...  in forest        %     NaN
# 1     NaN                   NaN        NaN  ...      cover    w.r.t     NaN
# 2     NaN                   NaN        NaN  ...      w.r.t     ISFR     NaN
# 3     NaN                   NaN        NaN  ...       ISFR     2017     NaN
# 4     NaN                   NaN        NaN  ...       2017      NaN     NaN
# 5      1.        Andhra Pradesh   1,62,968  ...        990     3.52   8,255
# 6      2.     Arunachal Pradesh     83,743  ...       -276    -0.41     229
# 7      3.                 Assam     78,438  ...        222     0.79     173
# 8      4.                 Bihar     94,163  ...          7     0.10     250
# 9      5.          Chhattisgarh   1,35,192  ...         64     0.12     610
# 10     6.                 Delhi      1,483  ...       3.03     1.57    0.30
# ...

# %%
data.head()
# Out:
#     S. State/UT       Geo. Unnamed: 3  ... % of     Change Change.1 Scrub
# 0  No.      NaN  Area (GA)        VDF  ...   GA  in forest        %   NaN
# 1  NaN      NaN        NaN        NaN  ...  NaN      cover    w.r.t   NaN
# 2  NaN      NaN        NaN        NaN  ...  NaN      w.r.t     ISFR   NaN
# 3  NaN      NaN        NaN        NaN  ...  NaN       ISFR     2017   NaN
# 4  NaN      NaN        NaN        NaN  ...  NaN       2017      NaN   NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# Changing the column names

# %%
data.columns=['index','s_No','State/UT','Geo_Area(GA)','VDF','2019_Assessment_MDF_OF','Total_Forest_Cover','change_in_forest_cover_wrt_ISFR_2017','change_1_per_wrt_ISFR_2017','scrub']

# %%
data=data.set_index('index')

# %%
data.head()
# Out:
#       s_No   State/UT  ... change_1_per_wrt_ISFR_2017 scrub
# index                  ...
# No.    NaN  Area (GA)  ...                          %   NaN
# NaN    NaN        NaN  ...                      w.r.t   NaN
# NaN    NaN        NaN  ...                       ISFR   NaN
# NaN    NaN        NaN  ...                       2017   NaN
# NaN    NaN        NaN  ...                        NaN   NaN
#
# [5 rows x 9 columns]

# %%
data.columns=['State/UT','Geo_Area(GA)','VDF','2019_Assessment_MDF_OF','Total_Forest_Cover','per_of_GA','change_in_forest_cover_wrt_ISFR_2017','change_1_per_wrt_ISFR_2017','scrub']

# %%
data
# Out:
#                    State/UT Geo_Area(GA)  ... change_1_per_wrt_ISFR_2017   scrub
# index                                     ...
# No.                     NaN    Area (GA)  ...                          %     NaN
# NaN                     NaN          NaN  ...                      w.r.t     NaN
# NaN                     NaN          NaN  ...                       ISFR     NaN
# NaN                     NaN          NaN  ...                       2017     NaN
# NaN                     NaN          NaN  ...                        NaN     NaN
# 1.           Andhra Pradesh     1,62,968  ...                       3.52   8,255
# 2.        Arunachal Pradesh       83,743  ...                      -0.41     229
# 3.                    Assam       78,438  ...                       0.79     173
# 4.                    Bihar       94,163  ...                       0.10     250
# 5.             Chhattisgarh     1,35,192  ...                       0.12     610
# ...

# %%
data.reset_index(drop=True, inplace=True)
data=data.drop(labels=[0,1,2,3,4], axis=0)

# %%
data
# Out:
#                 State/UT Geo_Area(GA)  ... change_1_per_wrt_ISFR_2017   scrub
# 5         Andhra Pradesh     1,62,968  ...                       3.52   8,255
# 6      Arunachal Pradesh       83,743  ...                      -0.41     229
# 7                  Assam       78,438  ...                       0.79     173
# 8                  Bihar       94,163  ...                       0.10     250
# 9           Chhattisgarh     1,35,192  ...                       0.12     610
# 10                 Delhi        1,483  ...                       1.57    0.30
# 11                   Goa        3,702  ...                       0.36       0
# 12               Gujarat     1,96,244  ...                       0.68   2,994
# 13               Haryana       44,212  ...                       0.88     154
# 14     Himachal  Pradesh       55,673  ...                       2.21     315
# 15             UT of J&K      53,258*  ...                       1.68     250
# ...

# %%
data.reset_index(drop=True, inplace=True)

# %%
x=data['2019_Assessment_MDF_OF'][0]

# %%
type(x)
# Out:
# str

# %%
y=x.split()

# %%
y
# Out:
# ['13,938', '13,205']

# %%
new = data['2019_Assessment_MDF_OF'].str.split(" ", n = 1, expand = True)

# %%
data['2019_Assessment_MDF']=new[0]
data['2019_Assessment_OF']=new[1]

# %%
data=data.drop(['2019_Assessment_MDF_OF'], axis=1)

# %%
data.rename(columns = {'VDF':'2019_Assessment_VDF','Total_Forest_Cover':'2019_Assessment_Total_Forest_Cover'}, inplace = True)

# %%
data.head()
# Out:
#             State/UT Geo_Area(GA)  ... 2019_Assessment_MDF 2019_Assessment_OF
# 0     Andhra Pradesh     1,62,968  ...              13,938             13,205
# 1  Arunachal Pradesh       83,743  ...              30,557             15,036
# 2              Assam       78,438  ...              10,279             15,253
# 3              Bihar       94,163  ...               3,280              3,693
# 4       Chhattisgarh     1,35,192  ...              32,198             16,345
#
# [5 rows x 10 columns]

# %%
data['per_of_GA'] = data['per_of_GA'].astype(float)

# %%
data
# Out:
#                 State/UT Geo_Area(GA)  ... 2019_Assessment_MDF 2019_Assessment_OF
# 0         Andhra Pradesh     1,62,968  ...              13,938             13,205
# 1      Arunachal Pradesh       83,743  ...              30,557             15,036
# 2                  Assam       78,438  ...              10,279             15,253
# 3                  Bihar       94,163  ...               3,280              3,693
# 4           Chhattisgarh     1,35,192  ...              32,198             16,345
# 5                  Delhi        1,483  ...               56.42             132.30
# 6                    Goa        3,702  ...                 576              1,123
# 7                Gujarat     1,96,244  ...               5,092              9,387
# 8                Haryana       44,212  ...                 451              1,123
# 9      Himachal  Pradesh       55,673  ...               7,126              5,195
# ...

# %%
data['Geo_Area(GA)']=data['Geo_Area(GA)'].str.replace(',', '')

# %%
data['Geo_Area(GA)']=data['Geo_Area(GA)'].str.replace('*', '')

# %%
data=data.drop(labels=[12], axis=0)

# %%
data
# Out:
#                 State/UT Geo_Area(GA)  ... 2019_Assessment_MDF 2019_Assessment_OF
# 0         Andhra Pradesh       162968  ...              13,938             13,205
# 1      Arunachal Pradesh        83743  ...              30,557             15,036
# 2                  Assam        78438  ...              10,279             15,253
# 3                  Bihar        94163  ...               3,280              3,693
# 4           Chhattisgarh       135192  ...              32,198             16,345
# 5                  Delhi         1483  ...               56.42             132.30
# 6                    Goa         3702  ...                 576              1,123
# 7                Gujarat       196244  ...               5,092              9,387
# 8                Haryana        44212  ...                 451              1,123
# 9      Himachal  Pradesh        55673  ...               7,126              5,195
# ...

# %%
data.reset_index(drop=True, inplace=True)

# %%
data['2019_Assessment_VDF']=data['2019_Assessment_VDF'].str.replace(',','')

# %%
data['2019_Assessment_Total_Forest_Cover']=data['2019_Assessment_Total_Forest_Cover'].str.replace(',','')
data['scrub']=data['scrub'].str.replace(',','')
data['2019_Assessment_MDF']=data['2019_Assessment_MDF'].str.replace(',','')
data['2019_Assessment_OF']=data['2019_Assessment_OF'].str.replace(',','')

# %%
data['change_in_forest_cover_wrt_ISFR_2017']=data['change_in_forest_cover_wrt_ISFR_2017'].str.replace(',','')

# %%
data['change_1_per_wrt_ISFR_2017']=data['change_1_per_wrt_ISFR_2017'].str.replace(',','')

# %%
data['Geo_Area(GA)']=data['Geo_Area(GA)'].astype(int)

# %%
data['2019_Assessment_VDF']=data['2019_Assessment_VDF'].astype(float)

# %%
data['2019_Assessment_Total_Forest_Cover']=data['2019_Assessment_Total_Forest_Cover'].astype(float)

# %%
data['scrub']=data['scrub'].astype(float)

# %%
data['2019_Assessment_MDF']=data['2019_Assessment_MDF'].astype(float)

# %%
data['2019_Assessment_OF']=data['2019_Assessment_OF'].astype(float)

# %%
data['change_in_forest_cover_wrt_ISFR_2017']=data['change_in_forest_cover_wrt_ISFR_2017'].replace('-','').astype(float)

# %%
data['change_1_per_wrt_ISFR_2017']=data['change_1_per_wrt_ISFR_2017'].replace('-','').astype(float)

# %%
data.at[38,'State/UT']='Total'

# %%
data.at[12,'State/UT']='J&K Total'

# %%
data.style.set_caption("2019 Forest covered statewise in india")
# Out:
# <style  type="text/css" >
# </style><table id="T_591dee2a_1018_11ec_aa7b_0242ac1c0002" ><caption>2019 Forest covered statewise in india</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >State/UT</th>        <th class="col_heading level0 col1" >Geo_Area(GA)</th>        <th class="col_heading level0 col2" >2019_Assessment_VDF</th>        <th class="col_heading level0 col3" >2019_Assessment_Total_Forest_Cover</th>        <th class="col_heading level0 col4" >per_of_GA</th>        <th class="col_heading level0 col5" >change_in_forest_cover_wrt_ISFR_2017</th>        <th class="col_heading level0 col6" >change_1_per_wrt_ISFR_2017</th>        <th class="col_heading level0 col7" >scrub</th>        <th class="col_heading level0 col8" >2019_Assessment_MDF</th>        <th class="col_heading level0 col9" >2019_Assessment_OF</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
data
# Out:
#                 State/UT  Geo_Area(GA)  ...  2019_Assessment_MDF  2019_Assessment_OF
# 0         Andhra Pradesh        162968  ...             13938.00            13205.00
# 1      Arunachal Pradesh         83743  ...             30557.00            15036.00
# 2                  Assam         78438  ...             10279.00            15253.00
# 3                  Bihar         94163  ...              3280.00             3693.00
# 4           Chhattisgarh        135192  ...             32198.00            16345.00
# 5                  Delhi          1483  ...                56.42              132.30
# 6                    Goa          3702  ...               576.00             1123.00
# 7                Gujarat        196244  ...              5092.00             9387.00
# 8                Haryana         44212  ...               451.00             1123.00
# 9      Himachal  Pradesh         55673  ...              7126.00             5195.00
# ...

# %%
data.describe()
# Out:
#        Geo_Area(GA)  ...  2019_Assessment_OF
# count  3.900000e+01  ...           39.000000
# mean   1.742979e+05  ...        15890.176667
# std    5.204374e+05  ...        48054.682470
# min    3.000000e+01  ...            6.430000
# 25%    1.353250e+04  ...         1123.000000
# 50%    5.567300e+04  ...         8967.000000
# 75%    1.593375e+05  ...        12129.000000
# max    3.287469e+06  ...       304499.000000
#
# [8 rows x 9 columns]

# %%
data.dtypes
# Out:
# State/UT                                 object
# Geo_Area(GA)                              int64
# 2019_Assessment_VDF                     float64
# 2019_Assessment_Total_Forest_Cover      float64
# per_of_GA                               float64
# change_in_forest_cover_wrt_ISFR_2017    float64
# change_1_per_wrt_ISFR_2017              float64
# scrub                                   float64
# 2019_Assessment_MDF                     float64
# 2019_Assessment_OF                      float64
# dtype: object

# %%
data.to_csv('2019_forest_cover_statewise_india.csv')

# %% [markdown]
# Example data
